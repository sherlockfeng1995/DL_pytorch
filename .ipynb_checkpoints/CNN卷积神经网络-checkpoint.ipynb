# %% [markdown]
# # 一、导论：

# %% [markdown]
# ![Snipaste_2020-08-20_10-52-30.png](attachment:Snipaste_2020-08-20_10-52-30.png)

# %% [markdown]
# 对卷积的理解：
#
# https://www.zhihu.com/question/22298352
#
# https://blog.csdn.net/bitcarmanlee/article/details/54729807
#
# https://mlnotebook.github.io/post/CNN1/

# %% [markdown]
# # 二、CNN卷积神经网络的原理及架构：

# %% [markdown]
# （1）介绍了为什么进行卷积操作及CNN的架构：
#
# https://www.jianshu.com/p/c0215d26d20a
#
# 对这篇博文的疑问主要是：1、激活函数是放在全连接层与输出层之间还是卷积层和前者都有？
#
# 2、对多个颜色通道进行卷积操作时，是分别对多个颜色通道的对应值相加还是单独计算每个颜色通道的卷积值？
#
# https://www.zhihu.com/question/266352189
#
# https://zhuanlan.zhihu.com/p/27908027
#
# https://zhuanlan.zhihu.com/p/28173972
#
# 这篇博文解决了我的疑问，激活函数放在卷积层之后，将每个颜色通道的卷积值进行相加。但是在进行最后全连接层的输出时，貌似有点问题。
#
# （2）介绍了CNN的原理及bp算法：
#
# https://blog.csdn.net/m0_37490039/article/details/79378143
#
# http://neuralnetworksanddeeplearning.com/chap6.html#convolutional_neural_networks_in_practice
#
# （3）介绍了卷积神经网络为什么进行池化操作，及其作用：
#
# https://www.cnblogs.com/MrSaver/p/10356695.html

# %% [markdown]
# # 三、深入理解CNN卷积神经网络每一个卷积层的作用：

# %% [markdown]
# https://www.jianshu.com/p/09f35a390ac2

# %% [markdown]
# # 四、CNN的经典模型：

# %% [markdown]
# https://www.jianshu.com/p/4a84885f787a

# %% [markdown]
# 参考资料：http://neuralnetworksanddeeplearning.com/chap6.html#convolutional_neural_networks_in_practice
#
# https://mlnotebook.github.io/post/CNN1/

# %% [markdown]
# # 五、疑问：

# %% [markdown]
# 不同通道的卷积值要进行累加吗？
# https://blog.csdn.net/qq_30979017/article/details/79424746
#
# 不同通道共享卷积核的参数吗？
#
# 3D卷积核的维度指的是2D+时间维度，即在2维和不同帧的图片上同时滑动。
# https://www.zhihu.com/question/266352189

# %% [markdown]
# # 六、三维卷积神经网络：C3D

# %% [markdown]
# https://www.zhihu.com/question/266352189

# %% [markdown]
# https://www.jianshu.com/p/eb29e624173e

# %% [markdown]
# https://blog.csdn.net/qq_33273962/article/details/83713402

# %% [markdown]
# 如果是RGB图片的话，不同颜色通道的卷积值需要相加。
#
# 而上面所说的不同特征的卷积值，不需要相加吗？
#
# 也就是说RGB通道的数量与geature map没有关系，而不同特征的通道数量与feature map有关？

# %% [markdown]
# https://www.jianshu.com/p/e46c74fa2c6d

# %% [markdown]
# 这篇文章解释了二维卷积时多通道的情况，以及三维卷积时多帧的情况：
#
#
# https://www.cnblogs.com/szxspark/p/8445406.html
