# %% [markdown]
# # 激活函数简介

# %% [markdown]
# https://mp.weixin.qq.com/s?__biz=MzA3MzI4MjgzMw==&mid=2650732724&idx=4&sn=5230b8bb1811cda38ab97afb417d1613&chksm=871b3ccab06cb5dcdf0bdfadcc7ae85d8ae95588bed0b884a55ba50b76d541771104675fbb3e&scene=21#wechat_redirect

# %% [markdown]
# 对此有疑问：为什么输出以0为中心会比较好？

# %% [markdown]
# sigmoid的输出不是0均值的,这会导致后一层的神经元将得到上一层输出的非0均值的信号作为输入。虽然解释了，但还是有疑问。
#
# https://www.cnblogs.com/XDU-Lakers/p/10557496.html

# %% [markdown]
# https://www.zhihu.com/question/290392414
# 梯度消失与梯度爆炸大多是因为激活函数与神经元相互作用，或者权重初始化过大

# %% [markdown]
# 二、softmax函数：
#
# https://blog.csdn.net/lz_peter/article/details/84574716

# %% [markdown]
# ![1527883835347.jpeg](attachment:1527883835347.jpeg)
#
# ![1527883835455.jpeg](attachment:1527883835455.jpeg)
#
# ![1527883835762.jpeg](attachment:1527883835762.jpeg)
